# %%
from IPython.display import Image

# %% [markdown]
# # Books Webscraping
#
# ## 1. Coletar os seguintes dados da página: https://books.toscrape.com
#     • Catálogo:
#         – Classics
#         – Science Fiction
#         – Humor
#         – Business
#
#     • Coletar os seguintes dados de cada livro:
#         – Nome do livro
#         – Preço em libras
#         – Avaliação dos consumidores
#         – Disponível em estoque

# %% [markdown]
# # Planejamento
# ### 1. Saida.
#     * A resposta para a pergunta
#         - Um csv com todas as informações de todos os catálogos.
#
#     * Formato da Entrega
#         - Um arquivo no formato csv.
#
#     * Local da Entrega
#         - E-Mail.
#
# ### 2. Processo.
#     * Passo a Passo para desenvolver o csv
#         - Salvar a coleta de dados em um csv.
#
#     * Definir o formato da Entrega
#         - Arquivo csv contendo as informações abaixo.
#         - Tabela com as colunas: book_id, book_name, book_category, book_price, book_evaluation, book_stock
#         - Definir o schema
#         - Entrega do produto final
#
#     * Decidir o local da entrega.
#         - Usuário informa o email para realizar o envio
#
# ### 3. Entrada.
#     * Fonte de dados
#         - https://books.toscrape.com
#
#     * Ferramentas
#         - Python 3.8.0
#         - Bibliotecas de Web Scraping ( BeautifulSoup )
#         - Bloco de Notas (Arquivo .py)
#         - Jupyter Notebook (Análises)
#         - Bibliotecas de Email (smtplib)

# %%
Image( '/img/simple.png' )
